# %%
import pandas as pd

# %%
df.head()
# Out:
#    Unnamed: 0  movieId                        title  \
# 0       72797     6888         Scary Movie 3 (2003)
# 1       94575    95508             Cleanskin (2012)
# 2       66988     5418  Bourne Identity, The (2002)
# 3       40612     2164   Surf Nazis Must Die (1987)
# 4       61308     4299      Knight's Tale, A (2001)
#
#                        genres  userId  rating
# 0               Comedy Horror     232     3.0
# 1        Crime Drama Thriller     448     3.5
# 2     Action Mystery Thriller     325     4.0
# 3  Action Comedy Drama Horror      50     1.0
# 4       Action Comedy Romance     483     3.0

# %%
df = df[['movieId','title','genres','userId','rating']]
df.head()
# Out:
#    movieId                        title                      genres  userId  \
# 0     6888         Scary Movie 3 (2003)               Comedy Horror     232
# 1    95508             Cleanskin (2012)        Crime Drama Thriller     448
# 2     5418  Bourne Identity, The (2002)     Action Mystery Thriller     325
# 3     2164   Surf Nazis Must Die (1987)  Action Comedy Drama Horror      50
# 4     4299      Knight's Tale, A (2001)       Action Comedy Romance     483
#
#    rating
# 0     3.0
# 1     3.5
# 2     4.0
# 3     1.0
# 4     3.0

# %%
df.to_csv('streaming_data.csv')
